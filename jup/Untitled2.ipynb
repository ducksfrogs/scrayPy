# %%
import requests
import lxml.html

# %%
response = requests.get('https://masan-yamaki.xyz/puki/')

# %%
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" ?>\n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ja">\n<head>\n <meta http-equiv="content-type" content="application/xhtml+xml; charset=UTF-8" />\n <meta http-equiv="content-style-type" content="text/css" />\n\n <title>FrontPage - PukiWiki</title>\n\n <link rel="SHORTCUT ICON" href="" />\n <link rel="stylesheet" type="text/css" media="screen" href="skin/pukiwiki.css.php?charset=Shift_JIS" charset="Shift_JIS" />\n <link rel="stylesheet" type="text/css" media="print"  href="skin/pukiwiki.css.php?charset=Shift_JIS&amp;media=print" charset="Shift_JIS" />\n <link rel="alternate" type="application/rss+xml" title="RSS" href="https://masan-yamaki.xyz/puki/?cmd=rss" />\n</head>\n<body>\n\n<div id="header">\n <a href="https://masan-yamaki.xyz/puki/?FrontPage"><img id="logo" src="image/pukiwiki.png" width="80" height="80" alt="[PukiWiki]" title="[PukiW
# ...

# %%
html = lxml.html.fromstring(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-79835417e43b> in <module>
# ----> 1 html = lxml.html.fromstring(response.text)
#
# ~/.bin/anaconda3/lib/python3.7/site-packages/lxml/html/__init__.py in fromstring(html, base_url, parser, **kw)
#     873     else:
#     874         is_full_html = _looks_like_full_html_unicode(html)
# --> 875     doc = document_fromstring(html, parser=parser, base_url=base_url, **kw)
#     876     if is_full_html:
#     877         return doc
#
# ~/.bin/anaconda3/lib/python3.7/site-packages/lxml/html/__init__.py in document_fromstring(html, parser, ensure_head_body, **kw)
#     759     if parser is None:
#     760         parser = html_parser
# --> 761     value = etree.fromstring(html, parser, **kw)
#     762     if value is None:
#     763         raise etree.ParserError(
#
# src/lxml/etree.pyx in lxml.etree.fromstring()
#
# ...
